# %%
# imports

import pandas as pd

# %%
# Reading csv

data = pd.read_csv('dermatology.csv')

# %%
# printing csv data

data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
# Checking if there are any missing values in any columns or not

data.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# pnl_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
# Getting all Nan values 

data['age'].loc[data['age'].isnull()]
# Out:
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 262   NaN
# 263   NaN
# 264   NaN
# 265   NaN
# Name: age, dtype: float64

# %%
# getting mean of age column

age_mean = data['age'].mean()
age_mean
# Out:
# 36.29608938547486

# %%
# imputing mean value inplace of Nan values

data = data.fillna(age_mean)

# %%
# checked all values are replaced

data['age'].loc[data['age'].isnull()]
# Out:
# Series([], Name: age, dtype: float64)

# %%
# getting all columns

data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'pnl_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'age', 'class'],
#       dtype='object')

# %%
# plotting distribution of age vs disease

import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(x="class", y="age", kind="box", data=data)

# %%
import numpy as np

# %%
# Creating new column 'disease_1' where class values are 1 

data['disease_1'] = np.where(data['class'] == 1 , 1, 0)

# %%
# there are two types of values 1 == belongs to class

data['disease_1'].unique()
# Out:
# array([0, 1])

# %%
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %% [markdown]
# # plotting contingency tables

# %%
pd.crosstab(index=data['erythema'], columns=data['class'])
# Out:
# class      1   2   3   4   5   6
# erythema
# 0          1   0   1   0   2   0
# 1          7   5   7  11  25   2
# 2         63  34  49  32  22  15
# 3         41  22  15   6   3   3

# %%
pd.crosstab(index=data['pnl_infiltrate'], columns=data['class'])
# Out:
# class            1   2   3   4   5   6
# pnl_infiltrate
# 0               34  17  72  43  52  17
# 1               37  23   0   6   0   3
# 2               35  20   0   0   0   0
# 3                6   1   0   0   0   0

# %%
pd.crosstab(index=data['scaling'], columns=data['class'])
# Out:
# class     1   2   3   4   5   6
# scaling
# 0         0   0   2   0   6   0
# 1        13   7  28  24  34   5
# 2        64  43  37  25  11  15
# 3        35  11   5   0   1   0

# %%
pd.crosstab(index=data['koebner_phenomenon'], columns=data['class'])
# Out:
# class                1   2   3   4   5   6
# koebner_phenomenon
# 0                   63  60  20   9  52  20
# 1                   27   0  18  25   0   0
# 2                   18   1  23  12   0   0
# 3                    4   0  11   3   0   0

# %%
pd.crosstab(index=data['clubbing_of_the_rete_ridges'], columns=data['class'])
# Out:
# class                         1   2   3   4   5   6
# clubbing_of_the_rete_ridges
# 0                             3  61  72  49  49  18
# 1                            15   0   0   0   2   2
# 2                            60   0   0   0   1   0
# 3                            34   0   0   0   0   0

# %%
pd.crosstab(index=data['polygonal_papules'], columns=data['class'])
# Out:
# class                1   2   3   4   5   6
# polygonal_papules
# 0                  112  61   3  49  52  20
# 1                    0   0   1   0   0   0
# 2                    0   0  41   0   0   0
# 3                    0   0  27   0   0   0

# %%
pd.crosstab(index=data['follicular_papules'], columns=data['class'])
# Out:
# class                 1   2   3   4   5   6
# follicular_papules
# 0                   109  60  72  49  43   0
# 1                     2   1   0   0   6   2
# 2                     1   0   0   0   3  12
# 3                     0   0   0   0   0   6

# %%
pd.crosstab(index=data['itching'], columns=data['class'])
# Out:
# class     1   2   3   4   5   6
# itching
# 0        55   9   2  33   8  11
# 1        22  16   9  10   7   8
# 2        21  25  28   5  20   1
# 3        14  11  33   1  17   0

# %%
pd.crosstab(index=data['oral_mucosal_involvement'], columns=data['class'])
# Out:
# class                       1   2   3   4   5   6
# oral_mucosal_involvement
# 0                         112  61   5  49  52  20
# 1                           0   0   9   0   0   0
# 2                           0   0  45   0   0   0
# 3                           0   0  13   0   0   0

# %%
pd.crosstab(index=data['fibrosis_of_the_papillary_dermis'], columns=data['class'])
# Out:
# class                               1   2   3   4   5   6
# fibrosis_of_the_papillary_dermis
# 0                                 112  61  70  49   0  20
# 1                                   0   0   0   0   8   0
# 2                                   0   0   2   0  21   0
# 3                                   0   0   0   0  23   0

# %%
pd.crosstab(index=data['definite_borders'], columns=data['class'])
# Out:
# class              1   2   3   4   5  6
# definite_borders
# 0                  0  21   1   9  23  5
# 1                 14  22  10  22  16  9
# 2                 73  18  42  18  11  6
# 3                 25   0  19   0   2  0

# %%
pd.crosstab(index=data['spongiosis'], columns=data['class'])
# Out:
# class         1   2   3   4   5  6
# spongiosis
# 0           112   4  35   2  40  6
# 1             0   2   6   7   7  6
# 2             0  35  20  31   4  6
# 3             0  20  11   9   1  2

# %% [markdown]
# # Plotting correlation matrix

# %%
plt.figure(figsize=(20,15))
ax = sns.heatmap(data.corr())

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# making Linear Regression function with priting MSE and R2 

def LinearRegression(X_train, X_test, y_train, y_test, xlabel, ylabel):

    regr = linear_model.LinearRegression()
    
    regr.fit(X_train, y_train)
    
    y_pred = regr.predict(X_test)
    
    print("Mean squared error(MSE): %.2f" % mean_squared_error(y_test, y_pred))
    
    print("Coefficient of determination(R2): %.2f" % r2_score(y_test, y_pred))
    
    plt.scatter(X_test, y_test, color="black")
    plt.plot(X_test, y_pred, color="blue", linewidth=3)
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Train Test splitting and ploting regression line

X = data['disease_1'].values.reshape(-1,1)
y = data['class'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

LinearRegression(X_train, X_test, y_train, y_test, 'disease_1', 'class' )
# Out:
# Mean squared error(MSE): 1.15
# Coefficient of determination(R2): 0.58

# %% [markdown]
# # Naive Bayes Classifier

# %%
# Using Naive Bayes Classifier with top features

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

X = data[['clubbing_of_the_rete_ridges', 'koebner_phenomenon', 'fibrosis_of_the_papillary_dermis', 'pnl_infiltrate', 'spongiosis']]
y = data['disease_1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

gnb.fit(X_train, y_train)

# making predictions on the testing set
y_pred = gnb.predict(X_test)
 
# comparing y_test with predicted y_pred
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 86.48648648648648

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
# Train Test splitting

X = data.drop(['class'], axis=1)
y = data['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
def MakeDTModel(Xtrain, Ytrain, split_type, max_leaf_nodes=5, max_depth=None):
    cart_classifier = DecisionTreeClassifier(criterion = split_type, 
                                         max_leaf_nodes=5,
                                         max_depth = None,
                                         random_state = 120).fit(Xtrain, Ytrain)
    return cart_classifier

# %%
from matplotlib.pyplot import figure

def displayTree(classifier, X):
    # Control the figure size
    figure(figsize=(10, 8), dpi=80)

    # Plot the tree
    cn = ['psoriasis', 'seboreic dermatitis', 'clubbing_of_the_rete_ridges', 'pityriasis', 'chronic dermatitis', 'pityriasis ruba pilaris']
    tree.plot_tree(classifier, feature_names=X.columns.values.tolist(), 
                                    class_names=cn,
                                    filled = True)
    
    
    # Print the text version of the tree
    text_representation = tree.export_text(classifier, 
                                           feature_names=X.columns.values.tolist())
    
    print(text_representation)
    
    return

# %%
cart_classifier = MakeDTModel(X_train, y_train, 'gini', max_leaf_nodes=5, max_depth=None)
displayTree(cart_classifier, X)
# Out:
# |--- disease_1 <= 0.50
# |   |--- vacuolisation_and_damage_of_basal_layer <= 0.50
# |   |   |--- fibrosis_of_the_papillary_dermis <= 0.50
# |   |   |   |--- koebner_phenomenon <= 0.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- koebner_phenomenon >  0.50
# |   |   |   |   |--- class: 4
# |   |   |--- fibrosis_of_the_papillary_dermis >  0.50
# |   |   |   |--- class: 5
# |   |--- vacuolisation_and_damage_of_basal_layer >  0.50
# |   |   |--- class: 3
# |--- disease_1 >  0.50
# |   |--- class: 1

# %%
# Record CART's classification accuracy on tarining and test datasets
score1 = round(cart_classifier.score(X_train, y_train), 2) # training score
score2 = round(cart_classifier.score(X_test, y_test), 2)   # testing score

print ("CART Training and Testing scores: %.2f, %.2f" %  (score1, score2))
# Out:
# CART Training and Testing scores: 0.91, 0.92

# %%
# function defination for Comfusion matrix

from sklearn.metrics import confusion_matrix
import seaborn as sns

def displayCM(classifier, Xtrain, Xtest, Ytrain, Ytest ):

    if classifier.criterion == 'gini':

        # Record CART's predictions
        cart_predictions = classifier.predict(Xtest)

         # Compute TP, TN, FP, FN values for CART
        cart_cm = confusion_matrix(y_true=Ytest, 
                                   y_pred = cart_predictions)

        # Print CART's confusion matrix
        print("CART_Confusion_Matrix")
        print()
        print(cart_cm)

        print('-'*80)

        # Visualize CART's confusion matrix as a heatmap
        print("HEATMAP_CART_Confusion_Matrix")
        plt.figure(figsize=(8,8))
        sns.heatmap(cart_cm, annot=True, 
                    linewidths=.5, square = True, cmap = 'Oranges_r', fmt='0.4g');

        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')


    if classifier.criterion == 'entropy':
        
        # Record C5's predictions
        c5_predictions = classifier.predict(Xtest)
    
        # Compute TP, TN, FP, FN values for CART
        c5_cm = confusion_matrix(y_true=Ytest, 
                                y_pred = c5_predictions)
        
        # Print C5's confusion matrix
        print("C5_Confusion_Matrix")
        print()
        print(c5_cm)

        print('-'*80)

        # Visualize C5's confusion matrix as a heatmap
        print("HEATMAP_C5_Confusion_Matrix")
        plt.figure(figsize=(8,8))
        sns.heatmap(c5_cm, annot=True, 
                    linewidths=.5, square = True, cmap = 'Oranges_r', fmt='0.4g');
        
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')

# %%
displayCM(cart_classifier, X_train, X_test, y_train, y_test )
# Out:
# CART_Confusion_Matrix
#
# [[24  0  0  0  0  0]
#  [ 0 11  0  0  0  0]
#  [ 0  0 14  0  0  0]
#  [ 0  1  0  8  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  5  0  0  0  0]]
# --------------------------------------------------------------------------------
# HEATMAP_CART_Confusion_Matrix

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
 
from sklearn import metrics 
 
# using metrics module for accuracy calculation
print("ACCURACY OF THE RandomForest MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.972972972972973

# %%
# Printing features according to importance 

feature_imp = pd.Series(clf.feature_importances_, index = X.columns).sort_values(ascending = False)
feature_imp
# Out:
# fibrosis_of_the_papillary_dermis            0.088507
# disease_1                                   0.084648
# clubbing_of_the_rete_ridges                 0.070814
# koebner_phenomenon                          0.053783
# thinning_of_the_suprapapillary_epidermis    0.049981
# elongation_of_the_rete_ridges               0.048717
# vacuolisation_and_damage_of_basal_layer     0.043263
# pnl_infiltrate                              0.042987
# spongiosis                                  0.040608
# band-like_infiltrate                        0.040493
# saw-tooth_appearance_of_retes               0.038879
# focal_hypergranulosis                       0.038521
# exocytosis                                  0.036258
# oral_mucosal_involvement                    0.028825
# itching                                     0.025766
# melanin_incontinence                        0.025122
# polygonal_papules                           0.024047
# follicular_horn_plug                        0.020748
# ...

# %% [markdown]
# # Summary

# %% [markdown]
# * We tried 4 different models LinearRegression, Naive Bayes, Decision Trees, Random Forest out of which Random Forest perform best in accuray.
#
# * we can improve the accuracy in Decision tree and Random Forest models by hypertuning it.
