# %% [markdown]
# <a href="https://colab.research.google.com/github/yash1908/IDS/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 2 (Python)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# importing data
df = pd.read_csv('lifeedata.csv')

# %%
df
# Out:
#          Country  Year  Life_Expectancy  Adult_Mortality  Alcohol  \
# 0    Afghanistan  2010             58.8              279     0.01
# 1    Afghanistan  2011             59.2              275     0.01
# 2    Afghanistan  2012             59.5              272     0.01
# 3    Afghanistan  2013             59.9              268     0.01
# 4    Afghanistan  2014             59.9              271     0.01
# ..           ...   ...              ...              ...      ...
# 202      Eritrea  2010             62.1              298     0.61
# 203      Eritrea  2011             62.9              286     0.62
# 204      Estonia  2010             75.6              137    14.97
# 205      Estonia  2011             76.1              138     0.01
# 206      Estonia  2012             76.3              135     0.01
#
#      Percentage_Expenditure   BMI  Total_Expenditure           GDP  \
# 0                 79.679367  16.7               9.20    553.328940
# ...

# %% [markdown]
# # 1.How does Adult Mortality rate affects Life Expectancy ?

# %%
df.plot(kind='scatter', x='Adult_Mortality', y='Life_Expectancy')
plt.show()

# %% [markdown]
# * we can see that as Adult_Mortality rate is increasing as the Life_Expectancy is decreasing.
# * therefore as Adult Mortality rate decreases the will be increase in life expectancy of humans.

# %%
Pcorr, _ = pearsonr(df['Adult_Mortality'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['Adult_Mortality'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)
# Out:
# Pearson Correlation:  -0.8099391465320298
# Spearman Correlation:  -0.7585380713385448

# %%
covariance = np.cov(df['Adult_Mortality'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Covariance:
# [[12586.27217298  -853.60571502]
#  [ -853.60571502    88.24959664]]

# %% [markdown]
# * Both Correlation and Covariance between Adult_mortality rate and human Life_Expectancy is negative.
# * Therefore there is negative impact adult mortality on human life expectancy

# %% [markdown]
# # 2.How does Life Expectancy has positive or negative correlation with features ?

# %% [markdown]
# ## a. Correlation of Life Expectancy with BMI

# %%
df.plot(kind='scatter', x='BMI', y='Life_Expectancy')
plt.show()

# %%
Pcorr, _ = pearsonr(df['BMI'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['BMI'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)

covariance = np.cov(df['BMI'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Pearson Correlation:  0.7275569225075271
# Spearman Correlation:  0.7418333960252059
# Covariance:
# [[393.65500539 135.606726  ]
#  [135.606726    88.24959664]]

# %% [markdown]
# * Positive correlation

# %% [markdown]
# ## b. Correlation of Life Expectancy with Alcohol

# %%
df.plot(kind='scatter', x='Alcohol', y='Life_Expectancy')
plt.show()

# %%
Pcorr, _ = pearsonr(df['Alcohol'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['Alcohol'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)

covariance = np.cov(df['Alcohol'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Pearson Correlation:  0.46990372649178375
# Spearman Correlation:  0.5047264260904979
# Covariance:
# [[19.34161129 19.41384595]
#  [19.41384595 88.24959664]]

# %% [markdown]
# * positive correlation

# %% [markdown]
# ## c. Correlation of Life Expectancy with Percentage Expenditure

# %%
df.plot(kind='scatter', x='Percentage_Expenditure', y='Life_Expectancy')
plt.show()

# %%
Pcorr, _ = pearsonr(df['Percentage_Expenditure'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['Percentage_Expenditure'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)

covariance = np.cov(df['Percentage_Expenditure'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Pearson Correlation:  0.46597894190966843
# Spearman Correlation:  0.6173162224115436
# Covariance:
# [[6.36807504e+06 1.10465520e+04]
#  [1.10465520e+04 8.82495966e+01]]

# %% [markdown]
# * positive correlation

# %% [markdown]
# ## d. Correlation of Life Expectancy with GDP

# %%
df.plot(kind='scatter', x='GDP', y='Life_Expectancy')
plt.show()

# %%
Pcorr, _ = pearsonr(df['GDP'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['GDP'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)

covariance = np.cov(df['GDP'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Pearson Correlation:  0.47640560073557053
# Spearman Correlation:  0.5734129303134455
# Covariance:
# [[2.19579066e+08 6.63175830e+04]
#  [6.63175830e+04 8.82495966e+01]]

# %% [markdown]
# * positive correlation

# %% [markdown]
# ## 3. What is the impact of Schooling on Life Expectancy ?

# %%
df.plot(kind='scatter', x='Schooling', y='Life_Expectancy')
plt.show()

# %% [markdown]
# * From the above plot it is clearly observed that there is a positive impact of schooling on Life Expectancy of humans, as there is more schooling the life expectancy of humans is increasing.

# %%
Pcorr, _ = pearsonr(df['Schooling'], df['Life_Expectancy'] )
Scorr, _ = spearmanr(df['Schooling'], df['Life_Expectancy'])
print('Pearson Correlation: ', Pcorr)
print('Spearman Correlation: ', Scorr)

covariance = np.cov(df['Schooling'], df['Life_Expectancy'])
print('Covariance:')
print(covariance)
# Out:
# Pearson Correlation:  0.8356684928206252
# Spearman Correlation:  0.8728504642417583
# Covariance:
# [[ 9.95862577 24.77365579]
#  [24.77365579 88.24959664]]

# %% [markdown]
# * Both Correlation and Covariance between Schooling and human Life_Expectancy is Positive.
# * Therefore there is positive impact of schooling on human life expectancy

# %% [markdown]
# ## Correlation Analysis of all features

# %%
ax = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# * From the above correlation plot we can see that the -
#   - most affecting(positive/negative) features to Life Expectancy are Adult Mortality, BMI, Schooling
#   - Average Affecting features are Alcohol, Percentage Expenditure, GDP
#   - Least affecting features are Year, Total Expenditure, Population

# %% [markdown]
# # Create and plot several linear regression models for life expectancy and independent variables

# %%
def LinearRegression(X_train, X_test, y_train, y_test):

    regr = linear_model.LinearRegression()
    
    regr.fit(X_train, y_train)
    
    y_pred = regr.predict(X_test)
    
    print("Mean squared error(MSE): %.2f" % mean_squared_error(y_test, y_pred))
    
    print("Coefficient of determination(R2): %.2f" % r2_score(y_test, y_pred))
    
    plt.scatter(X_test, y_test, color="black")
    plt.plot(X_test, y_pred, color="blue", linewidth=3)
    
    plt.xlabel('Schooling')
    plt.ylabel('Life Expectancy')
    plt.show()

# %% [markdown]
# ## Model of Schooling and Life Expectancy

# %%
X = df['Schooling'].values.reshape(-1,1)
y = df['Life_Expectancy'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)
LinearRegression(X_train, X_test, y_train, y_test)
# Out:
# Mean squared error(MSE): 25.95
# Coefficient of determination(R2): 0.60

# %% [markdown]
# ## Model of Adult Mortality and Life Expectancy

# %%
X = df['Adult_Mortality'].values.reshape(-1,1)
y = df['Life_Expectancy'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)
LinearRegression(X_train, X_test, y_train, y_test)
# Out:
# Mean squared error(MSE): 25.28
# Coefficient of determination(R2): 0.62

# %% [markdown]
# ## Model of BMI and Life Expectancy

# %%
X = df['BMI'].values.reshape(-1,1)
y = df['Life_Expectancy'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)
LinearRegression(X_train, X_test, y_train, y_test)
# Out:
# Mean squared error(MSE): 36.40
# Coefficient of determination(R2): 0.45

# %% [markdown]
# ## Model of Alcohol and Life Expectancy

# %%
X = df['Alcohol'].values.reshape(-1,1)
y = df['Life_Expectancy'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)
LinearRegression(X_train, X_test, y_train, y_test)
# Out:
# Mean squared error(MSE): 59.47
# Coefficient of determination(R2): 0.09

# %%
from prettytable import PrettyTable
table = PrettyTable()
table.field_names = ['Features',        'MSE',  'R2']
table.add_row(      ['Schooling',       25.95,  0.60])
table.add_row(      ['Adult Mortality', 25.38,  0.62])
table.add_row(      ['BMI',             36.40,  0.45])
table.add_row(      ['Alcohol',         59.47,  0.09])
print(table)
# Out:
# +-----------------+-------+------+
# |     Features    |  MSE  |  R2  |
# +-----------------+-------+------+
# |    Schooling    | 25.95 | 0.6  |
# | Adult Mortality | 25.38 | 0.62 |
# |       BMI       |  36.4 | 0.45 |
# |     Alcohol     | 59.47 | 0.09 |
# +-----------------+-------+------+

# %% [markdown]
# Acoording to results we can summarise that both Schooling and Adult Mortality rate feature models are performing best.
